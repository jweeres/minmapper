# %% [markdown]
# # Required packages
#
# ```
# pip install pandas
# pip install numpy
# pip install networkx
# pip install osmnx
# pip install scipy
# pip install garmin-fit-sdk
# pip install gpxpy
# pip install matplotlib
# pip install seaborn
# pip install line-profiler
# pip install geopandas
# pip install scikit-learn
# pip install shapely
# ```

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import networkx as nx
import osmnx as ox
from scipy import stats
from scipy.signal import find_peaks

from garmin_fit_sdk import Decoder, Stream
import gpxpy
from shapely import Polygon, LineString, count_coordinates
from shapely.validation import make_valid
import geopandas as gpd

import runtrack.matching as matching
import runtrack.matching.mpmatching as mpmatching
import runtrack.matching.mpmatching_utils as mpmatching_utils
import runtrack.analytics.visualization as viz

import matplotlib.pyplot as plt
import seaborn as sns

import os
import pickle
import time
from collections import deque

from line_profiler import LineProfiler

# %% [markdown]
# # Function Definitions

# %%
def create_cs_graph(place):
    print("creating citystrides graph", end=" ", flush=True)
    st = time.time()
    ox.settings.bidirectional_network_types = ["walk", "drive", "all"]

    with open("csquery.txt", encoding="utf-8") as file:
        filter = file.readline()
    if place == "Sunshine Hills":
        polygon = Polygon(
            (
                (-122.9186029, 49.1339211),
                (-122.9182107, 49.1339005),
                (-122.9173290, 49.1339171),
                (-122.9103271, 49.1339019),
                (-122.9035110, 49.1339256),
                (-122.8936911, 49.1340445),
                (-122.8936357, 49.1303340),
                (-122.8903685, 49.1303445),
                (-122.8903550, 49.1340870),
                (-122.8977329, 49.1194226),
                (-122.9002307, 49.1190351),
                (-122.9042114, 49.1190365),
                (-122.9076843, 49.1188845),
                (-122.9154025, 49.1187948),
                (-122.9159985, 49.1188319),
                (-122.9176966, 49.1191495),
                (-122.9182936, 49.1176611),
                (-122.9218904, 49.1175943),
                (-122.9219042, 49.1190088),
                (-122.9233853, 49.1189902),
                (-122.9236629, 49.1229190),
                (-122.9209377, 49.1276241),
            )
        )
        G = ox.graph.graph_from_polygon(
            make_valid(polygon),
            retain_all=True,
            truncate_by_edge=True,
            custom_filter=filter,
            simplify=False,
        )
        gdf = {
            "geometry": [polygon],
            "bbox_west": [
                G.nodes[min(G.nodes, key=lambda node: G.nodes[node]["x"])]["x"]
            ],
            "bbox_south": [
                G.nodes[min(G.nodes, key=lambda node: G.nodes[node]["y"])]["y"]
            ],
            "bbox_east": [
                G.nodes[max(G.nodes, key=lambda node: G.nodes[node]["x"])]["x"]
            ],
            "bbox_north": [
                G.nodes[max(G.nodes, key=lambda node: G.nodes[node]["y"])]["y"]
            ],
        }
        gdf = gpd.GeoDataFrame(gdf, crs="EPSG:4326")
    else:
        G = ox.graph.graph_from_place(
            place,
            retain_all=True,
            truncate_by_edge=True,
            custom_filter=filter,
            simplify=False,
        )
        gdf = ox.geocoder.geocode_to_gdf(place)
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")
    return nx.DiGraph(G), gdf

# %%
def in_bbox(lat, lng, gdf_row):
    return (
        lat.between(gdf_row["bbox_south"], gdf_row["bbox_north"]).any()
        and lng.between(gdf_row["bbox_west"], gdf_row["bbox_east"]).any()
    )

# %%
def create_routes(gdf, instance_name):
    print("creating list of routes:", end=" ", flush=True)
    st = time.time()
    activities_df = pd.read_csv(
        f"strava_data_{instance_name.split('-')[0]}/activities.csv", index_col=0
    )
    activities_df = activities_df[activities_df["Activity Type"].isin(["Run", "Walk"])]

    routes = {}
    j = 0
    fit_cnt = 0
    gpx_cnt = 0
    logs = [False] * 9
    for i, row in activities_df.iterrows():
        if False in logs and j / len(activities_df.index) > 1 / 10 * (
            logs.index(False) + 1
        ):
            logs[logs.index(False)] = True
            print(".", end=" ", flush=True)
        filename = f"strava_data_{instance_name.split('-')[0]}/" + row["Filename"]
        if filename[-3:] == ".gz":
            filename = filename[:-3]
        if os.path.isfile(filename):
            # handle .fit files
            if filename[-3:] == "fit":
                fit_cnt = fit_cnt + 1
                stream = Stream.from_file(filename)
                decoder = Decoder(stream)
                messages, errors = decoder.read(convert_datetimes_to_dates=True)
                try:
                    record = messages["record_mesgs"]
                except:
                    continue
                df = pd.DataFrame(record)
                try:
                    df = df.set_index("timestamp")[["position_lat", "position_long"]]
                except:
                    continue
                if df["position_lat"].max() > 90:
                    df = df / (2**32 / 360)
                if in_bbox(df["position_lat"], df["position_long"], gdf.loc[0]):
                    routes[i] = df
            # handle .gpx files
            elif filename[-3:] == "gpx":
                gpx_cnt = gpx_cnt + 1
                with open(filename, encoding="utf-8") as file:
                    gpx = gpxpy.parse(file)

                points = []
                for segment in gpx.tracks[0].segments:
                    for point in segment.points:
                        points.append(
                            {
                                "timestamp": point.time,
                                "position_lat": point.latitude,
                                "position_long": point.longitude,
                            }
                        )
                df = pd.DataFrame.from_records(points)
                try:
                    df = df.set_index("timestamp")
                except:
                    continue
                ## fix this!! (2**32/360)
                if df["position_lat"].max() > 90:
                    df = df / (2**32 / 360)
                if in_bbox(df["position_lat"], df["position_long"], gdf.loc[0]):
                    routes[i] = df
        j = j + 1
    with open(f"routes-{instance_name}.pkl", "wb") as file:
        pickle.dump(routes, file, pickle.HIGHEST_PROTOCOL)
    print(
        f"{fit_cnt} .fit and {gpx_cnt} .gpx files processed, {len(routes)} valid routes found.",
        end=" ",
        flush=True,
    )
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")

# %%
def create_composite_graph(G, gdf, instance_name, plot=True):
    with open(f"routes-{instance_name}.pkl", "rb") as file:
        routes = pickle.load(file)

    min_lat = None
    max_lat = None
    min_lng = None
    max_lng = None

    if instance_name == "jess-min":
        min_lat = gdf.loc[0]["bbox_south"]
        max_lat = gdf.loc[0]["bbox_north"]
        min_lng = gdf.loc[0]["bbox_east"]
        max_lng = gdf.loc[0]["bbox_west"]

        polygon = ox.utils_geo.bbox_to_poly([max_lng, min_lat, min_lng, max_lat])
        polygon = ox.utils_geo.buffer_geometry(polygon, 100)

        poly_gdf = gpd.GeoDataFrame({"geometry": [polygon]}, crs="EPSG:4326")

        for k, df in list(routes.items()):
            route_gdf = gpd.GeoDataFrame(
                df,
                geometry=gpd.points_from_xy(df.position_long, df.position_lat),
                crs="EPSG:4326",
            )
            # print(df)
            # print(gpd.sjoin(route_gdf,poly_gdf,predicate='within'))
            routes[k] = df.loc[
                df.index.isin(gpd.sjoin(route_gdf, poly_gdf, predicate="within").index)
            ]
            if routes[k].empty:
                del routes[k]
        print("creating route graphs", end=" ", flush=True)
        st = time.time()
        H1 = ox.graph_from_polygon(
            polygon,
            network_type="walk",
            retain_all=True,
            truncate_by_edge=True,
            simplify=False,
        )
        H2 = ox.graph_from_polygon(
            polygon,
            network_type="all",
            retain_all=True,
            truncate_by_edge=True,
            simplify=False,
            custom_filter='["highway"~"path"]["access"!~"no"]["access"!~"private"]["foot"!~"no"]["foot"!~"private"]["access"!~"discouraged"]["foot"!~"discouraged"]',
        )
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")

    else:
        print("finding route bounding box", end=" ", flush=True)
        st = time.time()

        for df in routes.values():
            # FIX THIS!! df = df/11930465
            if min_lat is None:
                min_lat = min(df["position_lat"].min(), gdf.loc[0]["bbox_south"])
                max_lat = max(df["position_lat"].max(), gdf.loc[0]["bbox_north"])
                min_lng = min(df["position_long"].min(), gdf.loc[0]["bbox_east"])
                max_lng = min(df["position_long"].max(), gdf.loc[0]["bbox_west"])

            if df["position_lat"].min() < min_lat:
                min_lat = df["position_lat"].min()
            if df["position_lat"].max() > max_lat:
                max_lat = df["position_lat"].max()
            if df["position_long"].min() < min_lng:
                min_lng = df["position_long"].min()
            if df["position_long"].max() > max_lng:
                max_lng = df["position_long"].max()

        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")

        print("creating route graphs", end=" ", flush=True)
        st = time.time()
        H1 = ox.graph_from_bbox(
            [max_lng, min_lat, min_lng, max_lat],
            network_type="walk",
            retain_all=True,
            truncate_by_edge=True,
            simplify=False,
        )
        H2 = ox.graph_from_bbox(
            [max_lng, min_lat, min_lng, max_lat],
            network_type="all",
            retain_all=True,
            truncate_by_edge=True,
            simplify=False,
            custom_filter='["highway"~"path"]["access"!~"no"]["access"!~"private"]["foot"!~"no"]["foot"!~"private"]["access"!~"discouraged"]["foot"!~"discouraged"]',
        )
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")
    print("creating composite graph", end=" ", flush=True)
    st = time.time()
    C = nx.compose(G, nx.compose(nx.DiGraph(H1), nx.DiGraph(H2)))

    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")
    if plot:
        print("plotting composite graph", end=" ", flush=True)
        st = time.time()
        fig, ax = ox.plot.plot_graph(
            C,
            show=False,
            close=False,
            bgcolor="#333333",
            edge_color="w",
            edge_linewidth=0.3,
            node_size=1,
            node_color="r",
        )
        plt.show()
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")

    return nx.DiGraph(C), routes

# %%
def add_visited_counts(C, routes, instance_name, plot=True):
    print("preparing candidates", end=" ", flush=True)
    st = time.time()
    nx.set_edge_attributes(C, 0, "visited")
    index, nodes, nodes_deg, rtree, coords, ball = matching.candidate.prep_candidates(
        C, interp_dist=None
    )
    saved_dists = {}
    j = 0
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")
    for id, df in routes.items():
        print(f"Route {j}/{len(routes)} --id:", id)
        df = df[df["position_lat"].notnull()]
        latitude = df["position_lat"].to_list()
        longitude = df["position_long"].to_list()

        points = [(lat, lng) for lat, lng in zip(latitude, longitude)]
        print("     ", j, "--finding candidates:", end=" ", flush=True)
        st = time.time()
        C_sub, candidates = matching.candidate.get_candidates(
            C,
            index,
            nodes,
            nodes_deg,
            rtree,
            coords,
            ball,
            points,
            closest=False,
            radius=10,
            plot=plot,
        )
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")

        print("     ", j, "--creating trellis", end=" ", flush=True)
        st = time.time()
        trellis = mpmatching_utils.create_trellis(candidates)
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")
        print("     ", j, "--performing matching:", end=" ", flush=True)
        st = time.time()
        path_prob, pred = mpmatching.viterbi_search(C_sub, trellis, saved_dists)
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")

        print("     ", j, "--saving path:", end=" ", flush=True)
        st = time.time()
        path_elabs = mpmatching_utils.create_path(C, trellis, pred)
        for path_elab in path_elabs:
            for u, v in zip(path_elab, path_elab[1:]):
                nx.set_edge_attributes(C, {(u, v): {"visited": C[u][v]["visited"] + 1}})
        if time.time() - st < 60:
            print(f"- {time.time() - st:.1f} s")
        else:
            print(f"- {(time.time() - st) / 60:.1f} m")
        j = j + 1

# %%
import math


def penalty_function(v_max, ub, mid, scale):
    if ub <= 1:
        return lambda v_count: ub

    b = (1 - ub) / (
        (1 - mid) / np.sqrt((1 - mid) ** 2 + scale**2)
        - (v_max - mid) / np.sqrt((v_max - mid) ** 2 + scale**2)
    )
    a = 1 - b * (1 - mid) / np.sqrt((1 - mid) ** 2 + scale**2)

    def penalty(v_count):
        y = a + b * (v_count - mid) / np.sqrt((v_count - mid) ** 2 + scale**2)
        return y

    return penalty


def add_profit_penalty(G, C, plot=True):
    print("calculating profit and penalty:", end=" ", flush=True)
    st = time.time()
    R = C.edge_subgraph(
        (edge[:2] for edge in C.edges(data="visited") if int(edge[2]) > 0)
    ).copy()
    R_G = R.copy()
    R_G.remove_nodes_from(n for n in R if n not in G)
    R_G.remove_edges_from(e for e in R.edges if e not in G.edges)

    df = nx.to_pandas_edgelist(R_G)
    vc = df["visited"].value_counts().rename("edges").to_frame().reset_index()
    vc = vc.sort_values(by=["visited"])
    vc = vc.reset_index(drop=True)

    r = R_G.size("length") / G.size("length")
    s = max(r / (1 - r) * vc["visited"].max(), 1)
    c = min(s, vc["visited"].max()) * (1 - r)

    kde = stats.gaussian_kde(df["visited"], weights=df["visited"])
    print(
        np.linspace(
            0,
            int(math.ceil(vc["visited"].max())),
            num=int(math.ceil(vc["visited"].max())) * 100 + 1,
        )
    )

    curve = pd.DataFrame(
        {
            "visited": np.linspace(
                0,
                int(math.ceil(vc["visited"].max())),
                num=int(math.ceil(vc["visited"].max())) * 100 + 1,
            )
        }
    )
    curve["kde"] = kde(curve["visited"])
    peaks, _ = find_peaks(curve["kde"])

    if plot or len(peaks) >= 2:
        vc["kde"] = kde(vc["visited"])
        vc["peaks"] = np.nan
        for peak in peaks:
            idx = (vc["visited"] - peak / 100).abs().argsort()[:1]
            vc.loc[vc.index[idx], "peaks"] = vc.loc[vc.index[idx], "kde"]
        mid = vc.loc[vc["peaks"].notna(), "visited"].values[1]

    if len(peaks) < 2:
        mid = df["visited"].max() / 2

    penalty = penalty_function(df["visited"].max(), c, mid, df["visited"].std() * 2)

    nx.set_edge_attributes(C, 0, "profit")
    nx.set_edge_attributes(C, penalty(0), "penalty")
    for src, tar in C.edges:
        if C[src][tar]["visited"] > 0:
            C[src][tar]["penalty"] = penalty(C[src][tar]["visited"])
        if "visitlength" in C[src][tar]:
            C[src][tar]["profit"] = s * sum(
                1 for val in C[src][tar]["visitlength"].values() if val == 0
            )
        elif C[src][tar]["visited"] == 0:
            C[src][tar]["profit"] = s

    print(
        f"{R.size('length') / C.size('length'):.0%} of C and {r:.0%} of G have been run.",
        end=" ",
        flush=True,
    )
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")

    if plot:
        sns.displot(df, x="visited")
        f, ax = plt.subplots()
        ax.set_xscale("log")
        ax.set_yscale("log")
        sns.despine(f)
        sns.scatterplot(vc, x="visited", y="edges")

        curve["kde"] = (
            curve["kde"]
            / kde(np.round(np.percentile(vc["visited"], 10)))
            * (vc["edges"])
            .loc[vc["visited"] == np.round(np.percentile(vc["visited"], 10))]
            .values
        )
        curve["s"] = s
        curve["c"] = c
        curve = curve.set_index("visited", drop=True)
        curve["sigmoid"] = penalty(curve.index.values)

        vc["kde"] = (
            vc["kde"]
            / kde(np.round(np.percentile(vc["visited"], 10)))
            * (vc["edges"])
            .loc[vc["visited"] == np.round(np.percentile(vc["visited"], 10))]
            .values
        )
        vc["peaks"] = (
            vc["peaks"]
            / kde(np.round(np.percentile(vc["visited"], 10)))
            * (vc["edges"])
            .loc[vc["visited"] == np.round(np.percentile(vc["visited"], 10))]
            .values
        )

        f, ax = plt.subplots()
        ax.set(ylim=(0, max(max(c, s) * 1.5, np.percentile(vc["edges"], 75))))
        sns.despine(f)
        sns.scatterplot(
            vc[["edges", "peaks"]].set_index(vc["visited"]), palette="flare_r"
        )
        sns.lineplot(curve, palette="crest")

# %%
import warnings


def remove_interior_node(G, node):
    for u in G.predecessors(node):
        for v in (v for v in G.successors(node) if u != v):
            data = G[u][node]
            if "nodes" not in data:
                data["nodes"] = {node}
            else:
                data["nodes"].add(node)
            for key, val in list(G[node][v].items()):
                if key not in data:
                    data[key] = val
                elif key == "length":
                    data[key] = data[key] + val
                elif key == "geometry":
                    data[key] = LineString(
                        list(dict.fromkeys(list(data[key].coords) + list(val.coords)))
                    )
                elif key == "visited":
                    if "visitlength" not in data:
                        data["visitlength"] = {
                            (u, node): data["visited"] * data["length"]
                        }
                    if "visitlength" not in G[node][v]:
                        G[node][v]["visitlength"] = {
                            (node, v): val * G[node][v]["length"]
                        }
                    data["visitlength"].update(G[node][v]["visitlength"])
                elif key == "visitlength":
                    continue
                elif key == "osmid":
                    if not isinstance(data[key], list):
                        data[key] = [data[key]]
                    if not isinstance(val, list):
                        val = [val]
                    data[key].extend(val)
                elif isinstance(data[key], set):
                    if not isinstance(val, set):
                        val = {val}
                    data[key].update(val)
                elif isinstance(val, set):
                    if not isinstance(data[key], set):
                        data[key] = {data[key]}
                    data[key].update(val)
                elif data[key] != val:
                    data[key] = {data[key], val}
                else:  # data[key] = val
                    continue
            G.add_edge(u, v, **data)
    G.remove_node(node)


def neighbor_set(G, node):
    return set(nx.all_neighbors(G, node))


def is_interior_node(G, node, ref_graph):
    return (
        node in G.nodes
        and (
            (
                G.in_degree(node) == 1
                and G.out_degree(node) == 1
                and set(G.predecessors(node)) != set(G.successors(node))
            )
            or (
                G.in_degree(node) == 2
                and G.out_degree(node) == 2
                and set(G.predecessors(node)) == set(G.successors(node))
            )
        )
        and no_edges_or_diff_attr(G, node)
    )


def no_edges_or_diff_attr(G, node):
    for u in G.predecessors(node):
        for v in G.successors(node):
            if G.has_edge(u, v):
                return False
    else:
        return True


def remove_interior_nodes(G, ref_graph=None):
    print("removing interior nodes:", end=" ", flush="True")
    st = time.time()
    orig_nodes = G.number_of_nodes()
    orig_edges = G.number_of_edges()
    orig_size = G.size("length")
    for node in list(G.nodes):
        if is_interior_node(G, node, ref_graph):
            queue = deque([node])
            while queue:
                u = queue.popleft()
                if is_interior_node(G, u, ref_graph):
                    queue.extend(neighbor_set(G, u))
                    remove_interior_node(G, u)
    for u, v, data in list(G.edges(data=True)):
        if "visitlength" in data:
            G[u][v]["visited"] = sum(data["visitlength"].values()) / (data["length"])
    print(
        f"{orig_nodes - G.number_of_nodes()} nodes and {orig_edges - G.number_of_edges()} edges removed. Total length was {orig_size}, now {G.size('length')}",
        end=" ",
        flush=True,
    )
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")

# %%
def to_undirected(G):
    H = nx.Graph()
    for u, v in G.edges:
        if G.has_edge(v, u):
            data = {}
            for key in set(G[u][v].keys()).union(set(G[v][u].keys())):
                if key in [
                    "length",
                    "visited",
                ]:
                    data[key] = G[u][v].get(key, 0) + G[v][u].get(key, 0)
                elif key == "geometry":
                    data[key] = G[u][v][key]
                elif key in [
                    "access",
                    "bridge",
                    "highway",
                    "junction",
                    "lanes",
                    "maxspeed",
                    "name",
                    "oneway",
                    "osmid",
                    "service",
                    "tunnel",
                ]:
                    if key in G[u][v] and key in G[v][u]:
                        if G[u][v][key] == G[v][u][key]:
                            data[key] = G[u][v][key]
                        else:
                            data[key] = [G[u][v][key], G[v][u][key]]
                    else:
                        data[key] = G[u][v].get(key, G[v][u].get(key))
                elif key in ["reversed"]:
                    continue
                else:
                    print(G[u][v])
                    print(G[v][u])
                    raise KeyError(f"Key {key} not handled")
        else:
            data = G[u][v]
            data.pop("reversed", None)  # remove reversed since no longer directed
        H.add_edge(u, v, **data)
    return H

# %%
def save_to_file(G, place, C, instance_name, tag=None):
    print("saving graphs to file", end=" ", flush=True)
    st = time.time()
    with open(f"G-{place.split(',')[0]}{'-' + tag if tag else ''}.pkl", "wb") as file:
        pickle.dump(G, file, pickle.HIGHEST_PROTOCOL)
    with open(f"instance-{instance_name}{'-' + tag if tag else ''}.pkl", "wb") as file:
        pickle.dump(C, file, pickle.HIGHEST_PROTOCOL)
    if time.time() - st < 60:
        print(f"- {time.time() - st:.1f} s")
    else:
        print(f"- {(time.time() - st) / 60:.1f} m")

    print("complete!")

# %% [markdown]
# # Creating the Instances

# %% [markdown]
# `instance-jess-min` has 3015 nodes, 6596 edges, and 67% of G has been run
#
# * `instance-jess-min-removed` has 1380 nodes and 3326 edges
#
# * `instance-jess-min-rem-aggressive` 1039 nodes and 2644 edges
#
# `instance-jess` has 84,756 nodes, 187,294 edges, and 21% of G has been run
#
# * `instance-jess-removed` has 28,873 nodes and 75,526 edges
#
# * `instance-jess-rem-aggressive` has 27,992 nodes and 73,764 edges
#
# `instance-jin` has 385,229 nodes, 867,782 edges, and 1% of G has been run
#
# * `instance-jin-min` has 101,579 nodes and 300,452 edges
#
# * `instance-jin-rem-aggressive` has 100,141 nodes and 297,576 edges

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Run everything above this box + the cell directly below to get the jin instances (including rem-aggressive). If you've already got the regular jin instances, it won't rerun them, so it tries to be as efficient as possible.</b>
# </div>

# %%
instance_name = "jin"  # 'jess-min','jess','jin'
place = "Toronto"  # 'Sunshine Hills','North Delta, BC, Canada','Toronto, ON, Canada'

if os.path.isfile(f"G-{place.split(',')[0]}.pkl"):
    with open(f"G-{place.split(',')[0]}.pkl", "rb") as file:
        G = pickle.load(file)
else:
    G, gdf = create_cs_graph(place)
if os.path.isfile(f"instance-{instance_name}.pkl"):
    with open(f"instance-{instance_name}.pkl", "rb") as file:
        C = pickle.load(file)
else:
    with open(f"routes-{instance_name}.pkl", "rb") as file:
        routes = pickle.load(file)
    C, routes = create_composite_graph(
        G, gdf, instance_name, plot=False
    )  # use plot=True to see entire city graph
    add_visited_counts(
        C, routes, instance_name, plot=False
    )  # use plot=True to see subgraph for each route
    G_copy = G.copy()
    C_copy = C.copy()
    add_profit_penalty(
        G_copy, C_copy, plot=True
    )  # use plot=True to see the distribution of visited counts
    save_to_file(G_copy, place, C_copy, instance_name)

### Show the graph of visited edges ###
print(C_copy.number_of_nodes(), C_copy.number_of_edges())
remove_interior_nodes(G_copy)
# fig, ax = ox.plot.plot_graph(nx.MultiDiGraph(G))
remove_interior_nodes(C_copy)
# fig, ax = ox.plot.plot_graph(nx.MultiDiGraph(C))
print(C_copy.number_of_nodes(), C_copy.number_of_edges())
# add_profit_penalty(
#     G, C, plot=True
# )  # use plot=True to see the distribution of visited counts
add_profit_penalty(
    G_copy, C_copy, plot=False
)  # use plot=True to see the distribution of visited counts
save_to_file(G_copy, place, C_copy, instance_name, "rem-aggressive")

### FOR PROFILING ###
# lp = LineProfiler()
# lp.add_function(matching.candidate.prep_candidates)
# lp.add_function(matching.candidate.get_candidates)
# lp.add_function(mpmatching_utils.create_trellis)
# lp.add_function(mpmatching.viterbi_search)
# lp.add_function(mpmatching_utils.transition_prob)
# lp.add_function(mpmatching_utils.create_path)
# lp_wrapper=lp(add_visited_counts)
# lp_wrapper(C, routes)
# lp.print_stats()
# Out:
# 100141 297576
# removing interior nodes: 0 nodes and 0 edges removed. Total length was 11594124.18872207, now 11594124.18872207 - 0.7 s
# removing interior nodes: 0 nodes and 0 edges removed. Total length was 19847189.314980846, now 19847189.314980846 - 6.6 s
# 100141 297576
# calculating profit and penalty: [0.000e+00 1.000e-02 2.000e-02 ... 2.398e+01 2.399e+01 2.400e+01]
# 1% of C and 0% of G have been run. - 2.1 s
# saving graphs to file - 10.3 s
# complete!

# %%
with open("instance-jess-min.pkl", "rb") as file:
    C = pickle.load(file)

remove_interior_nodes(C)
print(C.number_of_nodes(), C.number_of_edges())
# Out:
# removing interior nodes in
# 2    2006
# 3     544
# 1     303
# 4     161
# 5       1
# Name: count, dtype: int64
# out
# 2    2006
# 3     544
# 1     303
# 4     161
# 5       1
# Name: count, dtype: int64
# total
# 4     2006
# 6      544
# 2      303
# 8      161
# 10       1
# Name: count, dtype: int64
# 1798 nodes and 3640 edges removed. Total length was 189211.9663642301, now 186441.54530289903 - 0.2 s
# 1217 2956

# %% [markdown]
# # Visualizing Solutions

# %%
with open("instance-jess-min.pkl", "rb") as file:
    G = pickle.load(file)
for dist in ["1000", "5000", "8000", "10000", "15000"]:
    with open(f"sol_graph_instance-jess-min_{dist}_test.pkl", "rb") as file:
        sol = pickle.load(file)

    # Start node
    path = [6813225352]

    # Create the path list from the solution graph
    queue = deque()
    queue.append(path[0])
    while queue:
        u = queue.popleft()
        try:
            v = next(sol.successors(u))
            path.append(v)
            queue.append(v)
            sol[u][v]["visited"] = sol[u][v]["visited"] - 1
            if sol[u][v]["visited"] == 0:
                sol.remove_edge(u, v)
        except:
            pass

    # Plot the path
    fig, ax = ox.plot.plot_graph_route(G, route=path)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 26
#      23         pass
#      25 # Plot the path
# ---> 26 fig, ax = ox.plot.plot_graph_route(G, route=path)
#      27 plt.show()
#
# File c:\Users\Anthony Rachiero\.conda\envs\mie1603\Lib\site-packages\osmnx\plot.py:341, in plot_graph_route(G, route, route_color, route_linewidth, route_alpha, orig_dest_size, ax, **pg_kwargs)
#     339     overrides = {"show", "save", "close"}
#     340     kwargs = {k: v for k, v in pg_kwargs.items() if k not in overrides}
# --> 341     fig, ax = plot_graph(G, show=False, save=False, close=False, **kwargs)
#     342 else:
#     343     fig = ax.figure  # type: ignore[assignment]
#
# ...
